# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print(data)
# Out:
#                           name   mpg  cylinders  displacement  horsepower
# 0    chevrolet chevelle malibu  18.0          8         307.0       130.0  \
# 1            buick skylark 320  15.0          8         350.0       165.0
# 2           plymouth satellite  18.0          8         318.0       150.0
# 3                amc rebel sst  16.0          8         304.0       150.0
# 4                  ford torino  17.0          8         302.0       140.0
# ..                         ...   ...        ...           ...         ...
# 393            ford mustang gl  27.0          4         140.0        86.0
# 394                  vw pickup  44.0          4          97.0        52.0
# 395              dodge rampage  32.0          4         135.0        84.0
# 396                ford ranger  28.0          4         120.0        79.0
# 397                 chevy s-10  31.0          4         119.0        82.0
#
#      weight  acceleration  model_year  origin
# ...

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Null values exist in 'horsepower' column")

new_hp= np.mean(data.loc[~data.loc[:, "horsepower"].isna(), "horsepower"].values)
new_hp= np.round(new_hp)
data.loc[data.loc[:, "horsepower"].isna(), "horsepower"] = new_hp

print(data['horsepower'])
# Out:
# Null values exist in 'horsepower' column
# 0      130.0
# 1      165.0
# 2      150.0
# 3      150.0
# 4      140.0
#        ...
# 393     86.0
# 394     52.0
# 395     84.0
# 396     79.0
# 397     82.0
# Name: horsepower, Length: 398, dtype: float64

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("Now finding the statistical analysis of the dataset")
print("\n")
print("Statistical analysis of mpg (miles per gallon)")
print("Count=",data["mpg"].count())
print("Sum=",data["mpg"].sum())
print("Range=",data["mpg"].max()-data["mpg"].min())
print("Min=",data["mpg"].min())
print("Max=",data["mpg"].max())
print("Mean=",data["mpg"].mean())
print("Median=",data["mpg"].median())
print("Mode=",data["mpg"].mode())
print("Variance=",data["mpg"].var())
print("Standard deviation=",data["mpg"].std())
# Out:
# Now finding the statistical analysis of the dataset
#
#
# Statistical analysis of mpg (miles per gallon)
# Count= 398
# Sum= 9358.8
# Range= 37.6
# Min= 9.0
# Max= 46.6
# Mean= 23.514572864321607
# Median= 23.0
# Mode= 0    13.0
# Name: mpg, dtype: float64
# Variance= 61.089610774274405
# Standard deviation= 7.815984312565782

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of cylinders in a vehicle")
print("Count=",data["cylinders"].count())
print("Sum=",data["cylinders"].sum())
print("Range=",data["cylinders"].max()-data["cylinders"].min())
print("Min=",data["cylinders"].min())
print("Max=",data["cylinders"].max())
print("Mean=",data["cylinders"].mean())
print("Median=",data["cylinders"].median())
print("Mode=",data["cylinders"].mode())
print("Variance=",data["cylinders"].var())
print("Standard deviation=",data["cylinders"].std())
# Out:
# Statistical analysis of cylinders in a vehicle
# Count= 398
# Sum= 2171
# Range= 5
# Min= 3
# Max= 8
# Mean= 5.454773869346734
# Median= 4.0
# Mode= 0    4
# Name: cylinders, dtype: int64
# Variance= 2.893415439920003
# Standard deviation= 1.7010042445332119

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of the engine displacement of the vehicles")
print("Count=",data["displacement"].count())
print("Sum=",data["displacement"].sum())
print("Range=",data["displacement"].max()-data["displacement"].min())
print("Min=",data["displacement"].min())
print("Max=",data["displacement"].max())
print("Mean=",data["displacement"].mean())
print("Median=",data["displacement"].median())
print("Mode=",data["displacement"].mode())
print("Variance=",data["displacement"].var())
print("Standard deviation=",data["displacement"].std())
# Out:
# Statistical analysis of the engine displacement of the vehicles
# Count= 398
# Sum= 76983.5
# Range= 387.0
# Min= 68.0
# Max= 455.0
# Mean= 193.42587939698493
# Median= 148.5
# Mode= 0    97.0
# Name: displacement, dtype: float64
# Variance= 10872.199152247384
# Standard deviation= 104.26983817119591

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of the horsepower of the vehicles")
print("Count=",data["horsepower"].count())
print("Sum=",data["horsepower"].sum())
print("Range=",data["horsepower"].max()-data["horsepower"].min())
print("Min=",data["horsepower"].min())
print("Max=",data["horsepower"].max())
print("Mean=",data["horsepower"].mean())
print("Median=",data["horsepower"].median())
print("Mode=",data["horsepower"].mode())
print("Variance=",data["horsepower"].var())
print("Standard deviation=",data["horsepower"].std())
# Out:
# Statistical analysis of the horsepower of the vehicles
# Count= 393
# Sum= 41081.0
# Range= 184.0
# Min= 46.0
# Max= 230.0
# Mean= 104.53180661577608
# Median= 94.0
# Mode= 0    150.0
# Name: horsepower, dtype: float64
# Variance= 1479.3210520849561
# Standard deviation= 38.461942905747186

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of the weight of the vehicles")
print("Count=",data["weight"].count())
print("Sum=",data["weight"].sum())
print("Range=",data["weight"].max()-data["weight"].min())
print("Min=",data["weight"].min())
print("Max=",data["weight"].max())
print("Mean=",data["weight"].mean())
print("Median=",data["weight"].median())
print("Mode=",data["weight"].mode())
print("Variance=",data["weight"].var())
print("Standard deviation=",data["weight"].std())
# Out:
# Statistical analysis of the weight of the vehicles
# Count= 398
# Sum= 1182229
# Range= 3527
# Min= 1613
# Max= 5140
# Mean= 2970.424623115578
# Median= 2803.5
# Mode= 0    1985
# 1    2130
# Name: weight, dtype: int64
# Variance= 717140.9905256763
# Standard deviation= 846.8417741973268

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of the accelaration of the vehicles")
print("Count=",data["acceleration"].count())
print("Sum=",data["acceleration"].sum())
print("Range=",data["acceleration"].max()-data["acceleration"].min())
print("Min=",data["acceleration"].min())
print("Max=",data["acceleration"].max())
print("Mean=",data["acceleration"].mean())
print("Median=",data["acceleration"].median())
print("Mode=",data["acceleration"].mode())
print("Variance=",data["acceleration"].var())
print("Standard deviation=",data["acceleration"].std())
# Out:
# Statistical analysis of the accelaration of the vehicles
# Count= 398
# Sum= 6196.1
# Range= 16.8
# Min= 8.0
# Max= 24.8
# Mean= 15.568090452261307
# Median= 15.5
# Mode= 0    14.5
# Name: acceleration, dtype: float64
# Variance= 7.604848233611383
# Standard deviation= 2.757688929812676

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of the year in which the vehicle was manufactured")
print("Count=",data["model_year"].count())
print("Sum=",data["model_year"].sum())
print("Range=",data["model_year"].max()-data["model_year"].min())
print("Min=",data["model_year"].min())
print("Max=",data["model_year"].max())
print("Mean=",data["model_year"].mean())
print("Median=",data["model_year"].median())
print("Mode=",data["model_year"].mode())
print("Variance=",data["model_year"].var())
print("Standard deviation=",data["model_year"].std())
# Out:
# Statistical analysis of the year in which the vehicle was manufactured
# Count= 398
# Sum= 30252
# Range= 12
# Min= 70
# Max= 82
# Mean= 76.01005025125629
# Median= 76.0
# Mode= 0    73
# Name: model_year, dtype: int64
# Variance= 13.672442818627143
# Standard deviation= 3.697626646732623

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Statistical analysis of the place of origin of the vehicle")
a = data["origin"].mode().unique()
print("Most of the vehicles are from: ",a)
# Out:
# Statistical analysis of the place of origin of the vehicle
# Most of the vehicles are from:  ['usa']

# %%
import pandas as pd
import numpy as np
import statistics as stats
import time
data=pd.read_csv("Automobile.csv",header="infer")
print("\n")
print("Now we display the unique count from the dataset.")
print("\n")
name=data["name"].unique()
print("Name count=",data["name"].value_counts())
print("\n",name)
print("\n\n")


mpg=data["mpg"].unique()
print("Miles/Gallon count=",data["mpg"].value_counts(),end="")
print("\n",mpg)
print("\n\n")


cylinders=data["cylinders"].unique()
print("Cylinders count=",data["cylinders"].value_counts())
print("\n",cylinders)
print("\n\n")


displacement=data["displacement"].unique()
print("Displacement count=",data["displacement"].value_counts())
print("\n",displacement)
print("\n\n")


horsepower=data["horsepower"].unique()
print("Horsepower count=",data["horsepower"].value_counts())
print("\n",horsepower)
print("\n\n")


weight=data["weight"].unique()
print("Weight count=",data["weight"].value_counts())
print("\n",weight)
print("\n\n")


accelaration=data["acceleration"].unique()
print("Acceleration count=",data["acceleration"].value_counts())
print("\n",accelaration)
print("\n\n")


model_year=data["model_year"].unique()
print("Model year count=",data["model_year"].value_counts())
print("\n",model_year)
print("\n\n")


origin=data["origin"].unique()
print("Origin count=",data["origin"].value_counts())
print("\n",origin)
print("\n\n")
# Out:
# Now we display the unique count from the dataset.
#
#
# Name count= name
# ford pinto             6
# toyota corolla         5
# amc matador            5
# ford maverick          5
# chevrolet chevette     4
#                       ..
# chevrolet monza 2+2    1
# ford mustang ii        1
# pontiac astro          1
# amc pacer              1
# chevy s-10             1
# Name: count, Length: 305, dtype: int64
#
#  ['chevrolet chevelle malibu' 'buick skylark 320' 'plymouth satellite'
#  'amc rebel sst' 'ford torino' 'ford galaxie 500' 'chevrolet impala'
#  'plymouth fury iii' 'pontiac catalina' 'amc ambassador dpl'
#  'dodge challenger se' "plymouth 'cuda 340" 'chevrolet monte carlo'
#  'buick estate wagon (sw)' 'toyota corona mark ii' 'plymouth duster'
#  'amc hornet' 'ford maverick' 'datsun pl510'
#  'volkswagen 1131 deluxe sedan' 'peugeot 504' 'audi 100 ls' 'saab 99e'
#  'bmw 2002' 'amc gremlin' 'ford f250' 'chevy c20' 'dodge d200' 'hi 1200d'
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st

data = pd.read_csv("Automobile.csv",header="infer")
x_var = data["acceleration"]
y_var = data["horsepower"]
plt.figure(figsize=(10, 6))
plt.bar(x_var,y_var,color="red")
plt.xlabel("Acceleration")
plt.ylabel("Horsepower")
plt.title("Accelaration vs Horsepower")
plt.xticks(range(1,len(x_var) + 1, 30))
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st

data = pd.read_csv("Automobile.csv",header="infer")
plt.plot(data.index, data['acceleration'], color='red', linestyle='-')
plt.xlabel('Name')
plt.ylabel('Acceleration')
plt.title('Line graph of Acceleration')
plt.xticks(data.index, data['name'], rotation=90,fontsize=1)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st

data = pd.read_csv("Automobile.csv",header="infer")
plt.plot(data.index, data['horsepower'], color='blue', linestyle='-')
plt.xlabel('Name')
plt.ylabel('Horsepower')
plt.title('Line graph of Horsepower')
plt.xticks(data.index, data['name'], rotation=90,fontsize=1)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st

data = pd.read_csv("Automobile.csv",header="infer")
plt.plot(data.index, data['cylinders'], color='black', linestyle='-')
plt.xlabel('Name')
plt.ylabel('Cylinders')
plt.title('Line graph of Cylinders')
plt.xticks(data.index, data['name'], rotation=90,fontsize=1)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import statistics as st

data = pd.read_csv("Automobile.csv",header="infer")
plt.plot(data.index, data['mpg'], color='green', linestyle='-')
plt.xlabel('Name')
plt.ylabel('Miles per Gallon')
plt.title('Line graph of Miles/Gallon')
plt.xticks(data.index, data['name'], rotation=90,fontsize=1)
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.neighbors import KNeighborsRegressor
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
import math

data = pd.read_csv("Automobile.csv", header=0)

hp_mean = np.round(data.loc[~data["horsepower"].isna(), "horsepower"].mean())
data.loc[data["horsepower"].isna(), "horsepower"] = hp_mean

X = data.iloc[:, 1:6].values   
y = data.iloc[:, -3].values    

RANDOM_STATE = 42
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.2, random_state=RANDOM_STATE
)

pipeline = Pipeline([
    ("scaler", StandardScaler()),
    ("knn", KNeighborsRegressor())
])

param_grid = {
    "knn__n_neighbors": list(range(1, 21)),
    
}

grid = GridSearchCV(
    estimator=pipeline,
    param_grid=param_grid,
    scoring="r2",
    cv=5,
    n_jobs=-1,
    verbose=0
)

grid.fit(X_train, y_train)

best_k = grid.best_params_["knn__n_neighbors"]
best_score_cv = grid.best_score_ 

k_override = None 
if k_override is not None:
    knn_pipeline = Pipeline([
        ("scaler", StandardScaler()),
        ("knn", KNeighborsRegressor(n_neighbors=k_override))
    ])
    knn_pipeline.fit(X_train, y_train)
    chosen_k = k_override
else:
    knn_pipeline = grid.best_estimator_
    chosen_k = best_k

y_pred = knn_pipeline.predict(X_test)
r2 = r2_score(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = math.sqrt(mse)
mae = mean_absolute_error(y_test, y_pred)
mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100

print(f"Chosen k: {chosen_k}")
print(f"Test  Accuracy: {r2:.4f}")
print(f"MSE:  {mse:.4f}")
print(f"RMSE: {rmse:.4f}")
print(f"MAE:  {mae:.4f}")
print(f"MAPE: {mape:.2f}%")
# Out:
# Chosen k: 4
# Test  Accuracy: 0.6263
# MSE:  2.7579
# RMSE: 1.6607
# MAE:  1.2853
# MAPE: 8.21%
